# %%
import pandas as pd
import numpy as np
import pickle

from Code.dataImporter import *
from BUSPaS import *

# %% [markdown]
# ## Import data

# %%
#Pre-processed data
df_start, cat, num, features = getData('Stock5YSmall',countries='large_economies',attributes='expertBased')

#save set where original time-series are in target space
df_work = df_start.copy()
df_work = df_work.reset_index(drop=True)

#save set where original time-series are in target space
df_work['target'] = df_work['target'].apply(percent_change_norm)

#imports pre-calculated distance matrix, type dtype=float32 in numpy.ndarray in numpy.ndarray of equal size to nr_records
euclidean_slope_distance_matrix = np.load("C:/Users/bengelen004/Documents/TUe/BUSPas/New Submission WIP/Archive/20230602 Code/euclidean_slope_distance_matrix.npy")

threshold = 3000
df_work = df_work[:threshold]
euclidean_slope_distance_matrix = euclidean_slope_distance_matrix[:threshold,:threshold]
# Out:
# C:\Users\bengelen004\Documents\TUe\BUSPas\New Submission WIP\Code\dataImporter.py:165: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   descriptive_df = descriptive_df.replace("'", '', regex=True)
# C:\Users\bengelen004\Documents\TUe\BUSPas\New Submission WIP\Code\dataImporter.py:220: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_merge[col].replace(0, np.nan, inplace=True)

# %% [markdown]
# ## Run BUSPaS

# %%
bus = BUSPaS(df_work,
             euclidean_slope_distance_matrix,
             number_of_row_pairs=200,
             depth=3,
             q=20,
             z=2,
             nr_chunks=5,
             min_coverage_perc=0.01,
             min_coverage_abs=3)


bus.num_to_cat_attribute_converter()

bus.find_quality(quality_measure = cluster_based_quality_measure, comparison_type = "complement" , size_corr = no_size_corr)

bus.print_outcome()
# Out:
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "exchange == 'FRA'", "currency == 'EUR'"] to be checked
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "exchange == 'FRA'", "currency == 'EUR'"]  satisfies contraints
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "exchange == 'FRA'", "currency == 'EUR'"]  qual=  0.9195921
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "debtToEquity == '10.717 <= debtToEquity <= 35.683'"] to be checked
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "debtToEquity == '10.717 <= debtToEquity <= 35.683'"]  satisfies contraints
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "debtToEquity == '10.717 <= debtToEquity <= 35.683'"]  qual=  1.173321
# ["country == 'United Kingdom'"] to be checked
# ["country == 'United Kingdom'"]  satisfies contraints
# ["country == 'United Kingdom'"]  qual=  1.1502414
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "exchange == 'FRA'"] to be checked
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "exchange == 'FRA'"]  satisfies contraints
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "exchange == 'FRA'"]  qual=  0.9195921
# ["country == 'United States'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"] to be checked
# ["country == 'United States'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  satisfies contraints
# ["country == 'United States'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  qual=  0.92067873
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'"] to be checked
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'"]  satisfies contraints
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'"]  qual=  0.79368734
# ["exchangeTimezoneName == 'Europe/Berlin'", "country == 'United Kingdom'", "debtToEquity == '0.005 <= debtToEquity <= 10.717'"] to be checked
# ["currency == 'EUR'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"] to be checked
# ["currency == 'EUR'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"]  satisfies contraints
# ["currency == 'EUR'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"]  qual=  0.72377276
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "exchange == 'PNK'"] to be checked
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "exchange == 'PNK'"]  satisfies contraints
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "exchange == 'PNK'"]  qual=  1.0333892
# ["currency == 'USD'", "country == 'United States'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["currency == 'USD'", "country == 'United States'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["currency == 'USD'", "country == 'United States'", "exchangeTimezoneName == 'America/New_York'"]  qual=  1.0284711
# ["exchangeTimezoneName == 'Europe/Berlin'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"] to be checked
# ["exchangeTimezoneName == 'Europe/Berlin'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  satisfies contraints
# ["exchangeTimezoneName == 'Europe/Berlin'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  qual=  0.8735402
# ["currency == 'USD'", "exchange == 'NYQ'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["currency == 'USD'", "exchange == 'NYQ'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["currency == 'USD'", "exchange == 'NYQ'", "exchangeTimezoneName == 'America/New_York'"]  qual=  1.090779
# ["exchange == 'FRA'", "currency == 'EUR'"] to be checked
# ["exchange == 'FRA'", "currency == 'EUR'"]  satisfies contraints
# ["exchange == 'FRA'", "currency == 'EUR'"]  qual=  0.9191414
# ["industry == 'Banks—Regional'", "exchange == 'PNK'", "sector == 'Financial Services'"] to be checked
# ["industry == 'Banks—Regional'", "exchange == 'PNK'", "sector == 'Financial Services'"]  satisfies contraints
# ["industry == 'Banks—Regional'", "exchange == 'PNK'", "sector == 'Financial Services'"]  qual=  0.7895759
# ["sector == 'Industrials'", "currency == 'EUR'"] to be checked
# ["sector == 'Industrials'", "currency == 'EUR'"]  satisfies contraints
# ["sector == 'Industrials'", "currency == 'EUR'"]  qual=  0.8246898
# ["sector == 'Basic Materials'", "country == 'Canada'"] to be checked
# ["sector == 'Basic Materials'", "country == 'Canada'"]  satisfies contraints
# ["sector == 'Basic Materials'", "country == 'Canada'"]  qual=  1.0147775
# ["sector == 'Financial Services'"] to be checked
# ["sector == 'Financial Services'"]  satisfies contraints
# ["sector == 'Financial Services'"]  qual=  1.0640906
# ["averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "exchangeTimezoneName == 'America/New_York'"]  qual=  1.0937452
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'", "exchangeTimezoneName == 'Europe/Berlin'", "debtToEquity == '0.005 <= debtToEquity <= 10.717'"] to be checked
# ["currency == 'USD'", "fullTimeEmployees == '1.0 <= fullTimeEmployees <= 132.4000000000001'"] to be checked
# ["currency == 'USD'", "fullTimeEmployees == '1.0 <= fullTimeEmployees <= 132.4000000000001'"]  satisfies contraints
# ["currency == 'USD'", "fullTimeEmployees == '1.0 <= fullTimeEmployees <= 132.4000000000001'"]  qual=  1.1423352
# ["currency == 'USD'", "country == 'Canada'", "exchange == 'PNK'"] to be checked
# ["currency == 'USD'", "country == 'Canada'", "exchange == 'PNK'"]  satisfies contraints
# ["currency == 'USD'", "country == 'Canada'", "exchange == 'PNK'"]  qual=  0.93567014
# ["marketCap == '220155587.45420802 <= marketCap <= 1428907809.6670709'", "debtToEquity == '10.717 <= debtToEquity <= 35.683'"] to be checked
# ["marketCap == '220155587.45420802 <= marketCap <= 1428907809.6670709'", "debtToEquity == '10.717 <= debtToEquity <= 35.683'"]  satisfies contraints
# ["marketCap == '220155587.45420802 <= marketCap <= 1428907809.6670709'", "debtToEquity == '10.717 <= debtToEquity <= 35.683'"]  qual=  1.2694312
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "country == 'United States'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"] to be checked
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "country == 'United States'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  satisfies contraints
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "country == 'United States'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  qual=  1.0205921
# ["currency == 'USD'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["currency == 'USD'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["currency == 'USD'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "exchangeTimezoneName == 'America/New_York'"]  qual=  1.0441566
# ["exchangeTimezoneName == 'Europe/Berlin'", "country == 'United Kingdom'"] to be checked
# ["exchangeTimezoneName == 'Europe/Berlin'", "country == 'United Kingdom'"]  satisfies contraints
# ["exchangeTimezoneName == 'Europe/Berlin'", "country == 'United Kingdom'"]  qual=  1.3306985
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"] to be checked
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  satisfies contraints
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  qual=  1.2629173
# ["currency == 'USD'", "debtToEquity == '10.717 <= debtToEquity <= 35.683'"] to be checked
# ["currency == 'USD'", "debtToEquity == '10.717 <= debtToEquity <= 35.683'"]  satisfies contraints
# ["currency == 'USD'", "debtToEquity == '10.717 <= debtToEquity <= 35.683'"]  qual=  1.1298957
# ["industry == 'Banks—Regional'", "currency == 'USD'", "sector == 'Financial Services'"] to be checked
# ["industry == 'Banks—Regional'", "currency == 'USD'", "sector == 'Financial Services'"]  satisfies contraints
# ["industry == 'Banks—Regional'", "currency == 'USD'", "sector == 'Financial Services'"]  qual=  0.8875589
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"] to be checked
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  satisfies contraints
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  qual=  0.97692025
# ["enterpriseToEbitda == '15.4734 <= enterpriseToEbitda <= 3817.807'", "exchangeTimezoneName == 'Europe/Berlin'", "exchange == 'FRA'"] to be checked
# ["enterpriseToEbitda == '15.4734 <= enterpriseToEbitda <= 3817.807'", "exchangeTimezoneName == 'Europe/Berlin'", "exchange == 'FRA'"]  satisfies contraints
# ["enterpriseToEbitda == '15.4734 <= enterpriseToEbitda <= 3817.807'", "exchangeTimezoneName == 'Europe/Berlin'", "exchange == 'FRA'"]  qual=  0.967631
# ["fullTimeEmployees == '1076.0000000000005 <= fullTimeEmployees <= 4891.2'"] to be checked
# ["fullTimeEmployees == '1076.0000000000005 <= fullTimeEmployees <= 4891.2'"]  satisfies contraints
# ["fullTimeEmployees == '1076.0000000000005 <= fullTimeEmployees <= 4891.2'"]  qual=  1.1022602
# ["exchangeTimezoneName == 'Europe/Berlin'", "currency == 'EUR'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"] to be checked
# ["exchangeTimezoneName == 'Europe/Berlin'", "currency == 'EUR'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  satisfies contraints
# ["exchangeTimezoneName == 'Europe/Berlin'", "currency == 'EUR'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  qual=  0.8735402
# ["exchangeTimezoneName == 'America/Toronto'"] to be checked
# ["exchangeTimezoneName == 'America/Toronto'"]  satisfies contraints
# ["exchangeTimezoneName == 'America/Toronto'"]  qual=  1.091283
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "debtToEquity == '10.717 <= debtToEquity <= 35.683'", "country == 'United States'"] to be checked
# ["exchange == 'PNK'", "country == 'United States'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["exchange == 'PNK'", "country == 'United States'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["exchange == 'PNK'", "country == 'United States'", "exchangeTimezoneName == 'America/New_York'"]  qual=  0.9998096
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "currency == 'EUR'"] to be checked
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "currency == 'EUR'"]  satisfies contraints
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "currency == 'EUR'"]  qual=  0.95009845
# ["exchangeTimezoneName == 'Europe/Berlin'", "country == 'United States'", "currency == 'EUR'"] to be checked
# ["exchangeTimezoneName == 'Europe/Berlin'", "country == 'United States'", "currency == 'EUR'"]  satisfies contraints
# ["exchangeTimezoneName == 'Europe/Berlin'", "country == 'United States'", "currency == 'EUR'"]  qual=  0.83236945
# ["exchangeTimezoneName == 'Europe/Berlin'", "exchange == 'FRA'"] to be checked
# ["exchangeTimezoneName == 'Europe/Berlin'", "exchange == 'FRA'"]  satisfies contraints
# ["exchangeTimezoneName == 'Europe/Berlin'", "exchange == 'FRA'"]  qual=  0.9191414
# ["industry == 'Banks—Regional'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["industry == 'Banks—Regional'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["industry == 'Banks—Regional'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "exchangeTimezoneName == 'America/New_York'"]  qual=  0.76504827
# ["debtToEquity == '10.717 <= debtToEquity <= 35.683'", "country == 'United States'"] to be checked
# ["debtToEquity == '10.717 <= debtToEquity <= 35.683'", "country == 'United States'"]  satisfies contraints
# ["debtToEquity == '10.717 <= debtToEquity <= 35.683'", "country == 'United States'"]  qual=  1.1067971
# ["exchangeTimezoneName == 'America/New_York'", "sector == 'Financial Services'"] to be checked
# ["exchangeTimezoneName == 'America/New_York'", "sector == 'Financial Services'"]  satisfies contraints
# ["exchangeTimezoneName == 'America/New_York'", "sector == 'Financial Services'"]  qual=  1.0004213
# ["averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'", "country == 'United States'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'", "country == 'United States'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'", "country == 'United States'", "exchangeTimezoneName == 'America/New_York'"]  qual=  0.98088664
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'", "debtToEquity == '0.005 <= debtToEquity <= 10.717'"] to be checked
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'", "debtToEquity == '0.005 <= debtToEquity <= 10.717'"]  satisfies contraints
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'", "debtToEquity == '0.005 <= debtToEquity <= 10.717'"]  qual=  1.1828508
# ["averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "country == 'United States'"] to be checked
# ["averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "country == 'United States'"]  satisfies contraints
# ["averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "country == 'United States'"]  qual=  1.065251
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "currency == 'EUR'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"] to be checked
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "currency == 'EUR'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"]  satisfies contraints
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "currency == 'EUR'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"]  qual=  0.7283627
# ["currency == 'USD'", "fullTimeEmployees == '1.0 <= fullTimeEmployees <= 132.4000000000001'", "country == 'United States'"] to be checked
# ["currency == 'USD'", "fullTimeEmployees == '1.0 <= fullTimeEmployees <= 132.4000000000001'", "country == 'United States'"]  satisfies contraints
# ["currency == 'USD'", "fullTimeEmployees == '1.0 <= fullTimeEmployees <= 132.4000000000001'", "country == 'United States'"]  qual=  1.1163441
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "country == 'Canada'"] to be checked
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "country == 'Canada'"]  satisfies contraints
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "country == 'Canada'"]  qual=  1.0247139
# ["currency == 'USD'", "exchangeTimezoneName == 'America/New_York'", "exchange == 'PNK'"] to be checked
# ["currency == 'USD'", "exchangeTimezoneName == 'America/New_York'", "exchange == 'PNK'"]  satisfies contraints
# ["currency == 'USD'", "exchangeTimezoneName == 'America/New_York'", "exchange == 'PNK'"]  qual=  1.0099343
# ["industry == 'Banks—Regional'", "currency == 'USD'"] to be checked
# ["industry == 'Banks—Regional'", "currency == 'USD'"]  satisfies contraints
# ["industry == 'Banks—Regional'", "currency == 'USD'"]  qual=  0.8875589
# ["averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "exchange == 'FRA'"] to be checked
# ["averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "exchange == 'FRA'"]  satisfies contraints
# ["averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "exchange == 'FRA'"]  qual=  1.0480553
# ["exchange == 'PNK'", "exchangeTimezoneName == 'America/New_York'", "sector == 'Financial Services'"] to be checked
# ["exchange == 'PNK'", "exchangeTimezoneName == 'America/New_York'", "sector == 'Financial Services'"]  satisfies contraints
# ["exchange == 'PNK'", "exchangeTimezoneName == 'America/New_York'", "sector == 'Financial Services'"]  qual=  0.9152006
# ["debtToEquity == '35.683 <= debtToEquity <= 69.643'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"] to be checked
# ["debtToEquity == '35.683 <= debtToEquity <= 69.643'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  satisfies contraints
# ["debtToEquity == '35.683 <= debtToEquity <= 69.643'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  qual=  1.2924138
# ["currency == 'USD'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "sector == 'Financial Services'"] to be checked
# ["currency == 'USD'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "sector == 'Financial Services'"]  satisfies contraints
# ["currency == 'USD'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "sector == 'Financial Services'"]  qual=  0.82737964
# ["enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'", "country == 'United States'"] to be checked
# ["enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'", "country == 'United States'"]  satisfies contraints
# ["enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'", "country == 'United States'"]  qual=  0.8570181
# ["averageVolume10days == '14907.99999999999 <= averageVolume10days <= 201654.0000000001'"] to be checked
# ["averageVolume10days == '14907.99999999999 <= averageVolume10days <= 201654.0000000001'"]  satisfies contraints
# ["averageVolume10days == '14907.99999999999 <= averageVolume10days <= 201654.0000000001'"]  qual=  0.98604584
# ["sector == 'Industrials'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'"] to be checked
# ["sector == 'Industrials'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'"]  satisfies contraints
# ["sector == 'Industrials'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'"]  qual=  0.79160106
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'"] to be checked
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'"]  satisfies contraints
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'"]  qual=  0.8512649
# ["debtToEquity == '10.717 <= debtToEquity <= 35.683'", "enterpriseToEbitda == '3.5710000000000006 <= enterpriseToEbitda <= 8.468200000000001'"] to be checked
# ["debtToEquity == '10.717 <= debtToEquity <= 35.683'", "enterpriseToEbitda == '3.5710000000000006 <= enterpriseToEbitda <= 8.468200000000001'"]  satisfies contraints
# ["debtToEquity == '10.717 <= debtToEquity <= 35.683'", "enterpriseToEbitda == '3.5710000000000006 <= enterpriseToEbitda <= 8.468200000000001'"]  qual=  1.0217584
# ["currency == 'USD'", "country == 'United States'", "exchange == 'PNK'"] to be checked
# ["currency == 'USD'", "country == 'United States'", "exchange == 'PNK'"]  satisfies contraints
# ["currency == 'USD'", "country == 'United States'", "exchange == 'PNK'"]  qual=  0.9998096
# ["enterpriseToEbitda == '15.4734 <= enterpriseToEbitda <= 3817.807'", "exchangeTimezoneName == 'Europe/Berlin'", "currency == 'EUR'"] to be checked
# ["enterpriseToEbitda == '15.4734 <= enterpriseToEbitda <= 3817.807'", "exchangeTimezoneName == 'Europe/Berlin'", "currency == 'EUR'"]  satisfies contraints
# ["enterpriseToEbitda == '15.4734 <= enterpriseToEbitda <= 3817.807'", "exchangeTimezoneName == 'Europe/Berlin'", "currency == 'EUR'"]  qual=  0.9930811
# ["exchange == 'PNK'", "country == 'United States'", "sector == 'Financial Services'"] to be checked
# ["exchange == 'PNK'", "country == 'United States'", "sector == 'Financial Services'"]  satisfies contraints
# ["exchange == 'PNK'", "country == 'United States'", "sector == 'Financial Services'"]  qual=  0.84670395
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "country == 'United States'"] to be checked
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "country == 'United States'"]  satisfies contraints
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "country == 'United States'"]  qual=  1.153718
# ["sector == 'Energy'", "averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "marketCap == '19.0 <= marketCap <= 21935882.97344'"] to be checked
# ["currency == 'USD'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["currency == 'USD'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["currency == 'USD'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "exchangeTimezoneName == 'America/New_York'"]  qual=  1.0880007
# ["exchangeTimezoneName == 'America/New_York'", "exchange == 'PNK'", "sector == 'Technology'"] to be checked
# ["exchangeTimezoneName == 'America/New_York'", "exchange == 'PNK'", "sector == 'Technology'"]  satisfies contraints
# ["exchangeTimezoneName == 'America/New_York'", "exchange == 'PNK'", "sector == 'Technology'"]  qual=  1.1871339
# ["exchange == 'PNK'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'"] to be checked
# ["exchange == 'PNK'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'"]  satisfies contraints
# ["exchange == 'PNK'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'"]  qual=  1.0800102
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "currency == 'CAD'"] to be checked
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "currency == 'CAD'"]  satisfies contraints
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "currency == 'CAD'"]  qual=  1.0473967
# ["industry == 'Banks—Regional'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "sector == 'Financial Services'"] to be checked
# ["industry == 'Banks—Regional'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "sector == 'Financial Services'"]  satisfies contraints
# ["industry == 'Banks—Regional'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "sector == 'Financial Services'"]  qual=  0.78457826
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'"] to be checked
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'"]  satisfies contraints
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'"]  qual=  1.1550301
# ["country == 'United Kingdom'", "exchange == 'FRA'"] to be checked
# ["country == 'United Kingdom'", "exchange == 'FRA'"]  satisfies contraints
# ["country == 'United Kingdom'", "exchange == 'FRA'"]  qual=  1.3493575
# ["fullTimeEmployees == '1.0 <= fullTimeEmployees <= 132.4000000000001'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["fullTimeEmployees == '1.0 <= fullTimeEmployees <= 132.4000000000001'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["fullTimeEmployees == '1.0 <= fullTimeEmployees <= 132.4000000000001'", "exchangeTimezoneName == 'America/New_York'"]  qual=  1.1423352
# ["currency == 'USD'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["currency == 'USD'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["currency == 'USD'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'", "exchangeTimezoneName == 'America/New_York'"]  qual=  0.995048
# ["country == 'United Kingdom'", "exchange == 'FRA'", "currency == 'EUR'"] to be checked
# ["country == 'United Kingdom'", "exchange == 'FRA'", "currency == 'EUR'"]  satisfies contraints
# ["country == 'United Kingdom'", "exchange == 'FRA'", "currency == 'EUR'"]  qual=  1.3493575
# ["sector == 'Industrials'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"] to be checked
# ["sector == 'Industrials'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  satisfies contraints
# ["sector == 'Industrials'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  qual=  0.99166626
# ["country == 'United States'"] to be checked
# ["country == 'United States'"]  satisfies contraints
# ["country == 'United States'"]  qual=  0.9385966
# ["debtToEquity == '131.4486 <= debtToEquity <= 26549.602'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["debtToEquity == '131.4486 <= debtToEquity <= 26549.602'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["debtToEquity == '131.4486 <= debtToEquity <= 26549.602'", "exchangeTimezoneName == 'America/New_York'"]  qual=  0.9311459
# ["exchangeTimezoneName == 'Europe/Berlin'", "exchange == 'FRA'", "currency == 'EUR'"] to be checked
# ["exchangeTimezoneName == 'Europe/Berlin'", "exchange == 'FRA'", "currency == 'EUR'"]  satisfies contraints
# ["exchangeTimezoneName == 'Europe/Berlin'", "exchange == 'FRA'", "currency == 'EUR'"]  qual=  0.9191414
# ["fullTimeEmployees == '132.4000000000001 <= fullTimeEmployees <= 1076.0000000000005'", "averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["fullTimeEmployees == '132.4000000000001 <= fullTimeEmployees <= 1076.0000000000005'", "averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["fullTimeEmployees == '132.4000000000001 <= fullTimeEmployees <= 1076.0000000000005'", "averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'", "exchangeTimezoneName == 'America/New_York'"]  qual=  0.98442847
# ["country == 'Canada'", "industry == 'Other Precious Metals & Mining'"] to be checked
# ["currency == 'USD'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'"] to be checked
# ["currency == 'USD'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'"]  satisfies contraints
# ["currency == 'USD'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'"]  qual=  1.0465475
# ["currency == 'EUR'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"] to be checked
# ["currency == 'EUR'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"]  satisfies contraints
# ["currency == 'EUR'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"]  qual=  0.8684621
# ["industry == 'Banks—Regional'", "currency == 'USD'", "country == 'United States'"] to be checked
# ["industry == 'Banks—Regional'", "currency == 'USD'", "country == 'United States'"]  satisfies contraints
# ["industry == 'Banks—Regional'", "currency == 'USD'", "country == 'United States'"]  qual=  0.8751443
# ["enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"] to be checked
# ["enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"]  satisfies contraints
# ["enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"]  qual=  0.855386
# ["averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "currency == 'EUR'"] to be checked
# ["averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "currency == 'EUR'"]  satisfies contraints
# ["averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "currency == 'EUR'"]  qual=  1.0557153
# ["currency == 'USD'", "fullTimeEmployees == '132.4000000000001 <= fullTimeEmployees <= 1076.0000000000005'", "exchange == 'PNK'"] to be checked
# ["currency == 'USD'", "fullTimeEmployees == '132.4000000000001 <= fullTimeEmployees <= 1076.0000000000005'", "exchange == 'PNK'"]  satisfies contraints
# ["currency == 'USD'", "fullTimeEmployees == '132.4000000000001 <= fullTimeEmployees <= 1076.0000000000005'", "exchange == 'PNK'"]  qual=  1.0411006
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "averageVolume10days == '0.0 <= averageVolume10days <= 0.0'"] to be checked
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "averageVolume10days == '0.0 <= averageVolume10days <= 0.0'"]  satisfies contraints
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "averageVolume10days == '0.0 <= averageVolume10days <= 0.0'"]  qual=  1.0310291
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "country == 'United Kingdom'", "exchange == 'FRA'"] to be checked
# ["averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'"] to be checked
# ["averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'"]  satisfies contraints
# ["averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'"]  qual=  1.0532519
# ["fullTimeEmployees == '132.4000000000001 <= fullTimeEmployees <= 1076.0000000000005'", "exchange == 'PNK'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["fullTimeEmployees == '132.4000000000001 <= fullTimeEmployees <= 1076.0000000000005'", "exchange == 'PNK'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["fullTimeEmployees == '132.4000000000001 <= fullTimeEmployees <= 1076.0000000000005'", "exchange == 'PNK'", "exchangeTimezoneName == 'America/New_York'"]  qual=  1.0411006
# ["exchangeTimezoneName == 'Europe/Berlin'", "averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "exchange == 'FRA'"] to be checked
# ["exchangeTimezoneName == 'Europe/Berlin'", "averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "exchange == 'FRA'"]  satisfies contraints
# ["exchangeTimezoneName == 'Europe/Berlin'", "averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "exchange == 'FRA'"]  qual=  1.0480553
# ["sector == 'Basic Materials'"] to be checked
# ["sector == 'Basic Materials'"]  satisfies contraints
# ["sector == 'Basic Materials'"]  qual=  0.9465368
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"] to be checked
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  satisfies contraints
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  qual=  1.0828109
# ["debtToEquity == '35.683 <= debtToEquity <= 69.643'", "fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'"] to be checked
# ["averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "country == 'United States'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"] to be checked
# ["averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "country == 'United States'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  satisfies contraints
# ["averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "country == 'United States'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  qual=  1.2907416
# ["exchangeTimezoneName == 'Europe/Berlin'"] to be checked
# ["exchangeTimezoneName == 'Europe/Berlin'"]  satisfies contraints
# ["exchangeTimezoneName == 'Europe/Berlin'"]  qual=  0.94780177
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'"] to be checked
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'"]  satisfies contraints
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'"]  qual=  1.0288461
# ["currency == 'CAD'"] to be checked
# ["currency == 'CAD'"]  satisfies contraints
# ["currency == 'CAD'"]  qual=  1.091283
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'", "debtToEquity == '0.005 <= debtToEquity <= 10.717'", "fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'"] to be checked
# ["averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'"] to be checked
# ["averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'"]  satisfies contraints
# ["averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'"]  qual=  0.95853925
# ["exchangeTimezoneName == 'Europe/Berlin'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"] to be checked
# ["exchangeTimezoneName == 'Europe/Berlin'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"]  satisfies contraints
# ["exchangeTimezoneName == 'Europe/Berlin'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"]  qual=  0.8418511
# ["country == 'United States'", "sector == 'Technology'"] to be checked
# ["country == 'United States'", "sector == 'Technology'"]  satisfies contraints
# ["country == 'United States'", "sector == 'Technology'"]  qual=  1.1638901
# ["country == 'United Kingdom'", "currency == 'EUR'"] to be checked
# ["country == 'United Kingdom'", "currency == 'EUR'"]  satisfies contraints
# ["country == 'United Kingdom'", "currency == 'EUR'"]  qual=  1.3306985
# ["fullTimeEmployees == '132.4000000000001 <= fullTimeEmployees <= 1076.0000000000005'", "currency == 'USD'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["fullTimeEmployees == '132.4000000000001 <= fullTimeEmployees <= 1076.0000000000005'", "currency == 'USD'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["fullTimeEmployees == '132.4000000000001 <= fullTimeEmployees <= 1076.0000000000005'", "currency == 'USD'", "exchangeTimezoneName == 'America/New_York'"]  qual=  1.0237932
# ["exchange == 'PNK'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["exchange == 'PNK'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["exchange == 'PNK'", "exchangeTimezoneName == 'America/New_York'"]  qual=  1.0099343
# ["exchangeTimezoneName == 'America/Toronto'", "marketCap == '19.0 <= marketCap <= 21935882.97344'", "country == 'Canada'"] to be checked
# ["exchangeTimezoneName == 'America/Toronto'", "marketCap == '19.0 <= marketCap <= 21935882.97344'", "country == 'Canada'"]  satisfies contraints
# ["exchangeTimezoneName == 'America/Toronto'", "marketCap == '19.0 <= marketCap <= 21935882.97344'", "country == 'Canada'"]  qual=  1.0791485
# ["exchangeTimezoneName == 'America/Toronto'", "marketCap == '19.0 <= marketCap <= 21935882.97344'"] to be checked
# ["exchangeTimezoneName == 'America/Toronto'", "marketCap == '19.0 <= marketCap <= 21935882.97344'"]  satisfies contraints
# ["exchangeTimezoneName == 'America/Toronto'", "marketCap == '19.0 <= marketCap <= 21935882.97344'"]  qual=  1.0473967
# ["marketCap == '220155587.45420802 <= marketCap <= 1428907809.6670709'"] to be checked
# ["marketCap == '220155587.45420802 <= marketCap <= 1428907809.6670709'"]  satisfies contraints
# ["marketCap == '220155587.45420802 <= marketCap <= 1428907809.6670709'"]  qual=  0.89972806
# ["exchangeTimezoneName == 'America/New_York'", "country == 'United States'", "sector == 'Technology'"] to be checked
# ["exchangeTimezoneName == 'America/New_York'", "country == 'United States'", "sector == 'Technology'"]  satisfies contraints
# ["exchangeTimezoneName == 'America/New_York'", "country == 'United States'", "sector == 'Technology'"]  qual=  1.1120847
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'", "fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'"] to be checked
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'", "fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'"]  satisfies contraints
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'", "fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'"]  qual=  0.9707306
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "country == 'United Kingdom'"] to be checked
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "country == 'United Kingdom'"]  satisfies contraints
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "country == 'United Kingdom'"]  qual=  1.1327877
# ["averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'", "fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'"] to be checked
# ["averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'", "fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'"]  satisfies contraints
# ["averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'", "fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'"]  qual=  0.6460742
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'", "currency == 'EUR'", "fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'"] to be checked
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'", "currency == 'EUR'", "fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'"]  satisfies contraints
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'", "currency == 'EUR'", "fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'"]  qual=  0.97635895
# ["exchangeTimezoneName == 'America/Toronto'", "averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'", "marketCap == '19.0 <= marketCap <= 21935882.97344'"] to be checked
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "fullTimeEmployees == '1.0 <= fullTimeEmployees <= 132.4000000000001'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'"] to be checked
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "fullTimeEmployees == '1.0 <= fullTimeEmployees <= 132.4000000000001'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'"]  satisfies contraints
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "fullTimeEmployees == '1.0 <= fullTimeEmployees <= 132.4000000000001'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'"]  qual=  1.3165474
# ["exchangeTimezoneName == 'Europe/Berlin'", "sector == 'Basic Materials'"] to be checked
# ["exchangeTimezoneName == 'Europe/Berlin'", "sector == 'Basic Materials'"]  satisfies contraints
# ["exchangeTimezoneName == 'Europe/Berlin'", "sector == 'Basic Materials'"]  qual=  1.0058669
# ["exchangeTimezoneName == 'America/New_York'", "sector == 'Technology'"] to be checked
# ["exchangeTimezoneName == 'America/New_York'", "sector == 'Technology'"]  satisfies contraints
# ["exchangeTimezoneName == 'America/New_York'", "sector == 'Technology'"]  qual=  1.1331213
# ["averageVolume10days == '0.0 <= averageVolume10days <= 0.0'"] to be checked
# ["averageVolume10days == '0.0 <= averageVolume10days <= 0.0'"]  satisfies contraints
# ["averageVolume10days == '0.0 <= averageVolume10days <= 0.0'"]  qual=  1.0849813
# ["currency == 'USD'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["currency == 'USD'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["currency == 'USD'", "exchangeTimezoneName == 'America/New_York'"]  qual=  1.0405455
# ["debtToEquity == '35.683 <= debtToEquity <= 69.643'", "fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"] to be checked
# ["debtToEquity == '35.683 <= debtToEquity <= 69.643'", "fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  satisfies contraints
# ["debtToEquity == '35.683 <= debtToEquity <= 69.643'", "fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  qual=  1.1420484
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"] to be checked
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"]  satisfies contraints
# ["fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"]  qual=  0.80501693
# ["exchangeTimezoneName == 'Europe/Berlin'", "averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'"] to be checked
# ["exchangeTimezoneName == 'Europe/Berlin'", "averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'"]  satisfies contraints
# ["exchangeTimezoneName == 'Europe/Berlin'", "averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'"]  qual=  0.9488069
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "currency == 'USD'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "currency == 'USD'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["marketCap == '19.0 <= marketCap <= 21935882.97344'", "currency == 'USD'", "exchangeTimezoneName == 'America/New_York'"]  qual=  1.0091189
# ["enterpriseToEbitda == '15.4734 <= enterpriseToEbitda <= 3817.807'", "exchange == 'FRA'", "currency == 'EUR'"] to be checked
# ["enterpriseToEbitda == '15.4734 <= enterpriseToEbitda <= 3817.807'", "exchange == 'FRA'", "currency == 'EUR'"]  satisfies contraints
# ["enterpriseToEbitda == '15.4734 <= enterpriseToEbitda <= 3817.807'", "exchange == 'FRA'", "currency == 'EUR'"]  qual=  0.967631
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "country == 'United Kingdom'", "currency == 'EUR'"] to be checked
# ["currency == 'USD'", "averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["currency == 'USD'", "averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["currency == 'USD'", "averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "exchangeTimezoneName == 'America/New_York'"]  qual=  1.0937452
# ["exchangeTimezoneName == 'Europe/Berlin'", "currency == 'EUR'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"] to be checked
# ["exchangeTimezoneName == 'Europe/Berlin'", "currency == 'EUR'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"]  satisfies contraints
# ["exchangeTimezoneName == 'Europe/Berlin'", "currency == 'EUR'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"]  qual=  0.8418511
# ["averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "debtToEquity == '131.4486 <= debtToEquity <= 26549.602'", "fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'"] to be checked
# ["averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "debtToEquity == '131.4486 <= debtToEquity <= 26549.602'", "fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'"]  satisfies contraints
# ["averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "debtToEquity == '131.4486 <= debtToEquity <= 26549.602'", "fullTimeEmployees == '19515.200000000004 <= fullTimeEmployees <= 1608000.0'"]  qual=  0.64781886
# ["exchangeTimezoneName == 'Europe/Berlin'", "averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "currency == 'EUR'"] to be checked
# ["exchangeTimezoneName == 'Europe/Berlin'", "averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "currency == 'EUR'"]  satisfies contraints
# ["exchangeTimezoneName == 'Europe/Berlin'", "averageVolume10days == '0.0 <= averageVolume10days <= 0.0'", "currency == 'EUR'"]  qual=  1.0451256
# ["currency == 'USD'", "debtToEquity == '131.4486 <= debtToEquity <= 26549.602'"] to be checked
# ["currency == 'USD'", "debtToEquity == '131.4486 <= debtToEquity <= 26549.602'"]  satisfies contraints
# ["currency == 'USD'", "debtToEquity == '131.4486 <= debtToEquity <= 26549.602'"]  qual=  0.9311459
# ["enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'"] to be checked
# ...
# ["marketCap == '220155587.45420802 <= marketCap <= 1428907809.6670709'", "debtToEquity == '10.717 <= debtToEquity <= 35.683'", "enterpriseToEbitda == '3.5710000000000006 <= enterpriseToEbitda <= 8.468200000000001'"] to be checked
# ["marketCap == '220155587.45420802 <= marketCap <= 1428907809.6670709'", "debtToEquity == '10.717 <= debtToEquity <= 35.683'", "enterpriseToEbitda == '3.5710000000000006 <= enterpriseToEbitda <= 8.468200000000001'"]  satisfies contraints
# ["marketCap == '220155587.45420802 <= marketCap <= 1428907809.6670709'", "debtToEquity == '10.717 <= debtToEquity <= 35.683'", "enterpriseToEbitda == '3.5710000000000006 <= enterpriseToEbitda <= 8.468200000000001'"]  qual=  1.1877822
# ["debtToEquity == '10.717 <= debtToEquity <= 35.683'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'"] to be checked
# ["debtToEquity == '10.717 <= debtToEquity <= 35.683'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'"]  satisfies contraints
# ["debtToEquity == '10.717 <= debtToEquity <= 35.683'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'"]  qual=  1.3678142
# ["industry == 'Banks—Regional'", "exchange == 'PNK'"] to be checked
# ["industry == 'Banks—Regional'", "exchange == 'PNK'"]  satisfies contraints
# ["industry == 'Banks—Regional'", "exchange == 'PNK'"]  qual=  0.7895759
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'"] to be checked
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'"]  satisfies contraints
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'"]  qual=  1.0468906
# ["fullTimeEmployees == '1.0 <= fullTimeEmployees <= 132.4000000000001'", "country == 'United States'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["fullTimeEmployees == '1.0 <= fullTimeEmployees <= 132.4000000000001'", "country == 'United States'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["fullTimeEmployees == '1.0 <= fullTimeEmployees <= 132.4000000000001'", "country == 'United States'", "exchangeTimezoneName == 'America/New_York'"]  qual=  1.1163441
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"] to be checked
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  satisfies contraints
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  qual=  1.3479836
# ["exchangeTimezoneName == 'Europe/Berlin'", "exchange == 'FRA'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'"] to be checked
# ["exchangeTimezoneName == 'Europe/Berlin'", "exchange == 'FRA'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'"]  satisfies contraints
# ["exchangeTimezoneName == 'Europe/Berlin'", "exchange == 'FRA'", "averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'"]  qual=  0.8656909
# ["debtToEquity == '35.683 <= debtToEquity <= 69.643'"] to be checked
# ["debtToEquity == '35.683 <= debtToEquity <= 69.643'"]  satisfies contraints
# ["debtToEquity == '35.683 <= debtToEquity <= 69.643'"]  qual=  0.9616235
# ["fullTimeEmployees == '4891.2 <= fullTimeEmployees <= 19515.200000000004'", "country == 'United Kingdom'", "debtToEquity == '0.005 <= debtToEquity <= 10.717'"] to be checked
# ["country == 'United Kingdom'", "debtToEquity == '0.005 <= debtToEquity <= 10.717'", "currency == 'EUR'"] to be checked
# ["debtToEquity == '35.683 <= debtToEquity <= 69.643'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'"] to be checked
# ["debtToEquity == '35.683 <= debtToEquity <= 69.643'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'"]  satisfies contraints
# ["debtToEquity == '35.683 <= debtToEquity <= 69.643'", "averageVolume10days == '201654.0000000001 <= averageVolume10days <= 196561532.0'"]  qual=  0.97105914
# ["averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "country == 'United States'"] to be checked
# ["averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "country == 'United States'"]  satisfies contraints
# ["averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "country == 'United States'"]  qual=  0.7709484
# ["country == 'Canada'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'"] to be checked
# ["country == 'Canada'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'"]  satisfies contraints
# ["country == 'Canada'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'"]  qual=  1.0351899
# ["sector == 'Healthcare'", "marketCap == '21935882.97344 <= marketCap <= 220155587.45420802'", "averageVolume10days == '14907.99999999999 <= averageVolume10days <= 201654.0000000001'"] to be checked
# ["industry == 'Banks—Regional'", "exchange == 'PNK'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["industry == 'Banks—Regional'", "exchange == 'PNK'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["industry == 'Banks—Regional'", "exchange == 'PNK'", "exchangeTimezoneName == 'America/New_York'"]  qual=  0.7895759
# ["currency == 'EUR'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"] to be checked
# ["currency == 'EUR'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  satisfies contraints
# ["currency == 'EUR'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  qual=  0.88280565
# ["currency == 'USD'"] to be checked
# ["currency == 'USD'"]  satisfies contraints
# ["currency == 'USD'"]  qual=  1.0415751
# ["averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"] to be checked
# ["averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"]  satisfies contraints
# ["averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'"]  qual=  0.77383393
# ["marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"] to be checked
# ["marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  satisfies contraints
# ["marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  qual=  1.0567358
# ["exchangeTimezoneName == 'America/New_York'"] to be checked
# ["exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["exchangeTimezoneName == 'America/New_York'"]  qual=  1.0405455
# ["exchangeTimezoneName == 'America/Toronto'", "currency == 'CAD'"] to be checked
# ["exchangeTimezoneName == 'America/Toronto'", "currency == 'CAD'"]  satisfies contraints
# ["exchangeTimezoneName == 'America/Toronto'", "currency == 'CAD'"]  qual=  1.091283
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'"] to be checked
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'"]  satisfies contraints
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'"]  qual=  0.9789277
# ["exchangeTimezoneName == 'America/Toronto'", "averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'"] to be checked
# ["exchangeTimezoneName == 'America/Toronto'", "averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'"]  satisfies contraints
# ["exchangeTimezoneName == 'America/Toronto'", "averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'"]  qual=  1.118869
# ["exchangeTimezoneName == 'Europe/Berlin'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"] to be checked
# ["exchangeTimezoneName == 'Europe/Berlin'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  satisfies contraints
# ["exchangeTimezoneName == 'Europe/Berlin'", "enterpriseToEbitda == '8.468200000000001 <= enterpriseToEbitda <= 15.4734'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  qual=  0.7053671
# ["sector == 'Basic Materials'", "currency == 'EUR'"] to be checked
# ["sector == 'Basic Materials'", "currency == 'EUR'"]  satisfies contraints
# ["sector == 'Basic Materials'", "currency == 'EUR'"]  qual=  1.0331107
# ["averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'", "fullTimeEmployees == '132.4000000000001 <= fullTimeEmployees <= 1076.0000000000005'"] to be checked
# ["averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'", "fullTimeEmployees == '132.4000000000001 <= fullTimeEmployees <= 1076.0000000000005'"]  satisfies contraints
# ["averageVolume10days == '501.60000000000014 <= averageVolume10days <= 14907.99999999999'", "fullTimeEmployees == '132.4000000000001 <= fullTimeEmployees <= 1076.0000000000005'"]  qual=  0.9986277
# ["industry == 'Banks—Regional'", "currency == 'USD'", "exchangeTimezoneName == 'America/New_York'"] to be checked
# ["industry == 'Banks—Regional'", "currency == 'USD'", "exchangeTimezoneName == 'America/New_York'"]  satisfies contraints
# ["industry == 'Banks—Regional'", "currency == 'USD'", "exchangeTimezoneName == 'America/New_York'"]  qual=  0.8851485
# ["currency == 'USD'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'", "exchange == 'PNK'"] to be checked
# ["currency == 'USD'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'", "exchange == 'PNK'"]  satisfies contraints
# ["currency == 'USD'", "enterpriseToEbitda == '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'", "exchange == 'PNK'"]  qual=  1.0250651
# ["enterpriseToEbitda == '15.4734 <= enterpriseToEbitda <= 3817.807'", "currency == 'EUR'"] to be checked
# ["enterpriseToEbitda == '15.4734 <= enterpriseToEbitda <= 3817.807'", "currency == 'EUR'"]  satisfies contraints
# ["enterpriseToEbitda == '15.4734 <= enterpriseToEbitda <= 3817.807'", "currency == 'EUR'"]  qual=  1.022857
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'", "exchange == 'FRA'", "country == 'United States'"] to be checked
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'", "exchange == 'FRA'", "country == 'United States'"]  satisfies contraints
# ["marketCap == '1428907809.6670709 <= marketCap <= 6826143539.200006'", "exchange == 'FRA'", "country == 'United States'"]  qual=  0.94078517
# ["fullTimeEmployees == '1076.0000000000005 <= fullTimeEmployees <= 4891.2'", "sector == 'Financial Services'"] to be checked
# ["fullTimeEmployees == '1076.0000000000005 <= fullTimeEmployees <= 4891.2'", "sector == 'Financial Services'"]  satisfies contraints
# ["fullTimeEmployees == '1076.0000000000005 <= fullTimeEmployees <= 4891.2'", "sector == 'Financial Services'"]  qual=  1.2027097
# ["averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "debtToEquity == '131.4486 <= debtToEquity <= 26549.602'", "currency == 'EUR'"] to be checked
# ["averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "debtToEquity == '131.4486 <= debtToEquity <= 26549.602'", "currency == 'EUR'"]  satisfies contraints
# ["averageVolume10days == '0.0 <= averageVolume10days <= 501.60000000000014'", "debtToEquity == '131.4486 <= debtToEquity <= 26549.602'", "currency == 'EUR'"]  qual=  0.7207498
# ["debtToEquity == '35.683 <= debtToEquity <= 69.643'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"] to be checked
# ["debtToEquity == '35.683 <= debtToEquity <= 69.643'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  satisfies contraints
# ["debtToEquity == '35.683 <= debtToEquity <= 69.643'", "marketCap == '6826143539.200006 <= marketCap <= 1.0602763499077632e+16'"]  qual=  1.1623635
# after checking  376  potential subgroups
# Outcome of bottumUpSearch is:
#
# avg_quality =  1.329
# max_quality =  1.63
#
# avg_coverage =  0.026
# max_coverage =  0.081
#
# description = (10.717 <= debtToEquity <= 35.683) Ʌ (country='United States') Ʌ (6826143539.200006 <= marketCap <= 1.0602763499077632e+16)
# quality = 1.63
# coverage = 0.01
#
# description = (sector='Energy') Ʌ (0.0 <= averageVolume10days <= 0.0)
# quality = 1.492
# coverage = 0.013
#
# description = (currency='USD') Ʌ (6826143539.200006 <= marketCap <= 1.0602763499077632e+16)
# quality = 1.374
# coverage = 0.081
#
# description = (10.717 <= debtToEquity <= 35.683) Ʌ (-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006)
# quality = 1.368
# coverage = 0.033
#
# description = (currency='USD') Ʌ (6826143539.200006 <= marketCap <= 1.0602763499077632e+16) Ʌ (19515.200000000004 <= fullTimeEmployees <= 1608000.0)
# quality = 1.36
# coverage = 0.041
#
# description = (country='United Kingdom') Ʌ (exchange='FRA')
# quality = 1.349
# coverage = 0.011
#
# description = (4891.2 <= fullTimeEmployees <= 19515.200000000004) Ʌ (201654.0000000001 <= averageVolume10days <= 196561532.0) Ʌ (6826143539.200006 <= marketCap <= 1.0602763499077632e+16)
# quality = 1.348
# coverage = 0.018
#
# description = (exchangeTimezoneName='Europe/Berlin') Ʌ (country='United Kingdom')
# quality = 1.331
# coverage = 0.013
#
# description = (19.0 <= marketCap <= 21935882.97344) Ʌ (1.0 <= fullTimeEmployees <= 132.4000000000001) Ʌ (-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006)
# quality = 1.317
# coverage = 0.021
#
# description = (4891.2 <= fullTimeEmployees <= 19515.200000000004) Ʌ (0.005 <= debtToEquity <= 10.717)
# quality = 1.311
# coverage = 0.011
#
# description = (10.717 <= debtToEquity <= 35.683) Ʌ (6826143539.200006 <= marketCap <= 1.0602763499077632e+16)
# quality = 1.294
# coverage = 0.026
#
# description = (35.683 <= debtToEquity <= 69.643) Ʌ (201654.0000000001 <= averageVolume10days <= 196561532.0) Ʌ (6826143539.200006 <= marketCap <= 1.0602763499077632e+16)
# quality = 1.292
# coverage = 0.011
#
# description = (201654.0000000001 <= averageVolume10days <= 196561532.0) Ʌ (country='United States') Ʌ (6826143539.200006 <= marketCap <= 1.0602763499077632e+16)
# quality = 1.291
# coverage = 0.032
#
# description = (201654.0000000001 <= averageVolume10days <= 196561532.0) Ʌ (6826143539.200006 <= marketCap <= 1.0602763499077632e+16)
# quality = 1.28
# coverage = 0.053
#
# description = (4891.2 <= fullTimeEmployees <= 19515.200000000004) Ʌ (10.717 <= debtToEquity <= 35.683) Ʌ (6826143539.200006 <= marketCap <= 1.0602763499077632e+16)
# quality = 1.27
# coverage = 0.011
#
# description = (220155587.45420802 <= marketCap <= 1428907809.6670709) Ʌ (10.717 <= debtToEquity <= 35.683)
# quality = 1.269
# coverage = 0.032
#
# description = (19515.200000000004 <= fullTimeEmployees <= 1608000.0) Ʌ (201654.0000000001 <= averageVolume10days <= 196561532.0) Ʌ (6826143539.200006 <= marketCap <= 1.0602763499077632e+16)
# quality = 1.263
# coverage = 0.026
#
# description = (19.0 <= marketCap <= 21935882.97344) Ʌ (501.60000000000014 <= averageVolume10days <= 14907.99999999999) Ʌ (country='Canada')
# quality = 1.253
# coverage = 0.015
#
# description = (0.005 <= debtToEquity <= 10.717) Ʌ (currency='EUR')
# quality = 1.249
# coverage = 0.043
#
# description = (sector='Basic Materials') Ʌ (country='Australia')
# quality = 1.245
# coverage = 0.026

# %%
bus.run_statistical_test(k=3)
# Out:
# [(np.float32(1.3165474),
#   0.020666666666666667,
#   ['1.0 <= fullTimeEmployees <= 132.4000000000001',
#    '19.0 <= marketCap <= 21935882.97344',
#    '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'],
#   np.float64(0.25)),
#  (np.float32(1.148476),
#   0.151,
#   ['0.005 <= debtToEquity <= 10.717'],
#   np.float64(0.75)),
#  (np.float32(1.1392821),
#   0.019333333333333334,
#   ["sector == 'Industrials'", '0.005 <= debtToEquity <= 10.717'],
#   np.float64(0.75)),
#  (np.float32(1.1309248),
#   0.15033333333333335,
#   ['10.717 <= debtToEquity <= 35.683'],
#   np.float64(1.0)),
#  (np.float32(1.1150023),
#   0.162,
#   ['-2573.0 <= enterpriseToEbitda <= -3.354999999999999'],
#   np.float64(1.0)),
#  (np.float32(1.0849813),
#   0.22433333333333333,
#   ['0.0 <= averageVolume10days <= 0.0'],
#   np.float64(1.0)),
#  (np.float32(1.0786772),
#   0.146,
#   ['1.0 <= fullTimeEmployees <= 132.4000000000001'],
#   np.float64(1.0)),
#  (np.float32(1.0680653),
#   0.16533333333333333,
#   ["country == 'Canada'"],
#   np.float64(1.0)),
#  (np.float32(1.0667696),
#   0.06633333333333333,
#   ["country == 'United States'",
#    "exchange == 'PNK'",
#    '19.0 <= marketCap <= 21935882.97344'],
#   np.float64(1.0)),
#  (np.float32(1.0567358),
#   0.19633333333333333,
#   ['6826143539.200006 <= marketCap <= 1.0602763499077632e+16'],
#   np.float64(1.0)),
#  (np.float32(1.0557153),
#   0.12266666666666666,
#   ["currency == 'EUR'", '0.0 <= averageVolume10days <= 0.0'],
#   np.float64(1.0)),
#  (np.float32(1.0532594),
#   0.19633333333333333,
#   ['19.0 <= marketCap <= 21935882.97344'],
#   np.float64(1.0)),
#  (np.float32(1.0532519),
#   0.2,
#   ['201654.0000000001 <= averageVolume10days <= 196561532.0'],
#   np.float64(1.0)),
#  (np.float32(1.0480553),
#   0.10866666666666666,
#   ["currency == 'EUR'",
#    '0.0 <= averageVolume10days <= 0.0',
#    "exchange == 'FRA'"],
#   np.float64(1.0)),
#  (np.float32(1.0451256),
#   0.118,
#   ['0.0 <= averageVolume10days <= 0.0',
#    "exchangeTimezoneName == 'Europe/Berlin'"],
#   np.float64(1.0)),
#  (np.float32(1.0415751),
#   0.44633333333333336,
#   ["currency == 'USD'"],
#   np.float64(1.0)),
#  (np.float32(1.0405455),
#   0.44566666666666666,
#   ["exchangeTimezoneName == 'America/New_York'"],
#   np.float64(1.0)),
#  (np.float32(1.0405455),
#   0.44566666666666666,
#   ["currency == 'USD'", "exchangeTimezoneName == 'America/New_York'"],
#   np.float64(1.0)),
#  (np.float32(1.0344734),
#   0.035,
#   ['1.0 <= fullTimeEmployees <= 132.4000000000001',
#    '-3.354999999999999 <= enterpriseToEbitda <= 3.5710000000000006'],
#   np.float64(1.0)),
#  (np.float32(1.0333892),
#   0.098,
#   ["exchange == 'PNK'", '19.0 <= marketCap <= 21935882.97344'],
#   np.float64(1.0))]

# %%
from Code.diversity import *

# %%
bus_result = bus.result.copy()

# %%
df_work.query(as_string(bus_result[0][2]))
# Out:
#                       sector currency                        industry  \
# 110              Industrials      USD         Industrial Distribution
# 118                   Energy      EUR                   Oil & Gas E&P
# 166               Healthcare      USD  Medical Instruments & Supplies
# 267        Consumer Cyclical      USD        Residential Construction
# 414               Technology      USD            Software—Application
# 455               Healthcare      ILA          Diagnostics & Research
# 470        Consumer Cyclical      EUR        Residential Construction
# 494                   Energy      USD                   Oil & Gas E&P
# 496          Basic Materials      USD             Agricultural Inputs
# 562               Healthcare      EUR                 Medical Devices
# 563       Financial Services      USD                Asset Management
# 638        Consumer Cyclical      USD        Residential Construction
# 714       Financial Services      EUR           Insurance—Diversified
# 733               Technology      EUR         Software—Infrastructure
# 737   Communication Services      EUR  Internet Content & Information
# 752              Industrials      EUR  Integrated Freight & Logistics
# 1096             Industrials      USD         Industrial Distribution
# 1379             Industrials      USD  Staffing & Employment Services
# 1468             Industrials      USD  Specialty Industrial Machinery
# 1586              Technology      USD            Software—Application
# 1647       Consumer Cyclical      USD               Personal Services
# 2192      Financial Services      MXN           Insurance—Diversified
# 2366                  Energy      MXN                   Oil & Gas E&P
# 2418              Healthcare      USD  Medical Instruments & Supplies
# 2448              Healthcare      EUR  Medical Instruments & Supplies
# 2586      Financial Services      USD   Insurance—Property & Casualty
# 2587                  Energy      EUR            Oil & Gas Integrated
# 2679                  Energy      EUR            Oil & Gas Integrated
# 2794              Technology      MXN                  Semiconductors
# 2811       Consumer Cyclical      EUR              Auto Manufacturers
#
#      exchange        country exchangeTimezoneName  averageVolume10days  \
# 110       NMS  United States     America/New_York            2581600.0
# 118       GER  United States        Europe/Berlin                777.0
# 166       PNK  United States     America/New_York                  0.0
# 267       NYQ  United States     America/New_York            1961490.0
# 414       NMS  United States     America/New_York             415290.0
# 455       TLV  United States       Asia/Jerusalem             562970.0
# 470       FRA  United States        Europe/Berlin                  4.0
# 494       NYQ  United States     America/New_York            6114580.0
# 496       NYQ  United States     America/New_York            3675320.0
# 562       FRA  United States        Europe/Berlin                 81.0
# 563       NYQ  United States     America/New_York             678110.0
# 638       NYQ  United States     America/New_York            2139490.0
# 714       GER  United States        Europe/Berlin               9010.0
# 733       FRA  United States        Europe/Berlin                  9.0
# 737       GER  United States        Europe/Berlin              22967.0
# 752       FRA  United States        Europe/Berlin                  0.0
# 1096      NYQ  United States     America/New_York                 20.0
# 1379      NMS  United States     America/New_York            1363630.0
# 1468      NYQ  United States     America/New_York             893560.0
# 1586      NMS  United States     America/New_York             428030.0
# 1647      NYQ  United States     America/New_York            1848720.0
# 2192      MEX  United States  America/Mexico_City                356.0
# 2366      MEX  United States  America/Mexico_City               9846.0
# 2418      NMS  United States     America/New_York             580570.0
# 2448      FRA  United States        Europe/Berlin                  0.0
# 2586      NYQ  United States     America/New_York              28330.0
# 2587      GER  United States        Europe/Berlin              13478.0
# 2679      FRA  United States        Europe/Berlin               1066.0
# 2794      MEX  United States  America/Mexico_City               1076.0
# 2811      GER  United States        Europe/Berlin              73867.0
#
#       debtToEquity     marketCap  fullTimeEmployees  enterpriseToEbitda  \
# 110         25.588  2.891344e+10            19519.0              17.099
# 118         33.805  1.661916e+11             9400.0               5.734
# 166         27.302  3.337847e+10             8160.0              11.345
# 267         32.980  2.999756e+10            11788.0               4.210
# 414         12.636  1.132386e+10             5300.0             113.772
# 455         16.427  9.991828e+10             5767.0             -90.204
# 470         24.744  2.630437e+10            10753.0               3.790
# 494         33.805  1.638795e+11             9400.0               5.626
# 496         34.713  1.879090e+10            12525.0               3.941
# 562         11.488  4.660333e+10            15700.0              29.704
# 563         22.073  1.084687e+11            18400.0              13.386
# 638         34.441  1.143135e+10             6182.0               3.572
# 714         25.355  6.966060e+11           372000.0               0.849
# 733         11.838  5.226221e+10            16361.0              32.566
# 737         13.262  3.012231e+11            83553.0               7.087
# 752         14.226  1.914272e+10            19070.0               6.030
# 1096        14.058  1.077085e+10             6850.0              10.947
# 1379        28.020  4.541931e+10            16000.0              19.862
# 1468        18.471  9.627709e+09            13700.0              10.818
# 1586        19.887  2.099569e+10             5300.0              28.578
# 1647        33.350  1.987386e+10            16482.0              35.465
# 2192        25.355  7.116387e+11           372000.0               1.149
# 2366        33.805  1.707409e+11             9400.0             107.403
# 2418        23.080  9.260272e+09             1852.0              38.829
# 2448        27.302  3.309923e+10             8160.0              30.702
# 2586        33.947  1.764031e+10            20300.0              27.401
# 2587        25.410  4.690845e+11            63000.0               6.856
# 2679        25.410  4.715549e+11            63000.0               6.925
# 2794        15.180  6.179258e+10            48000.0              66.927
# 2811        14.284  1.850389e+11            99290.0              43.050
#
#                                                  target
# 110   [0.0, 4.390149387012583, 4.905515794550698, 4....
# 118   [0.0, 4.392399583641113, 9.77513597886561, 7.3...
# 166   [0.0, 0.0, 27.785057061095774, 27.522927867600...
# 267   [0.0, 0.0, -3.9553563145378137, -17.9557435358...
# 414   [0.0, 2.2106642203218367, 13.329002182992369, ...
# 455   [0.0, -4.555680539932508, -12.767154105736783,...
# 470   [0.0, 0.4148869101393924, -3.2828975815638857,...
# 494   [0.0, 7.8812858438521785, 15.58569209650674, 6...
# 496   [0.0, 5.6401765345714585, 12.391923458549837, ...
# 562   [0.0, -4.675719677415866, 2.5942586910076946, ...
# 563   [0.0, 2.498058514787255, 12.093215159184739, 9...
# 638   [0.0, -2.5783798434666467, -6.738942491736034,...
# 714   [0.0, 0.0, 6.51769062830027, 6.784601031460004...
# 733   [0.0, -6.9926501753246075, -2.8849438745740605...
# 737   [0.0, 0.33715440978480377, 2.4949405745803395,...
# 752   [0.0, 1.2110661406067535, -1.5864695870533305,...
# 1096  [0.0, 1.428402924354061, 7.922225779533478, 2....
# 1379  [0.0, 1.1439671674191405, 1.3965272255254093, ...
# 1468  [0.0, -3.3743289994232843, 5.2980143603927825,...
# 1586  [0.0, -0.4048897318514217, 9.082928155291821, ...
# 1647  [0.0, 0.3883491370127199, 6.4509122079846986, ...
# 2192  [0.0, 10.956230833565654, 11.235015333147476, ...
# 2366  [0.0, 17.282608695652176, 22.282608695652176, ...
# 2418  [0.0, 2.3413201650058295, -0.2256751180054245,...
# 2448  [0.0, 0.0, 12.3202689603941, 10.02630674944045...
# 2586  [0.0, 2.9117336487376932, 3.6850588212589157, ...
# 2587  [0.0, 0.0, 1.0137536818318325, -8.559020131656...
# 2679  [0.0, 0.028566632952008928, -0.057144165039062...
# 2794  [0.0, 2.1784993543787405, 3.0226042252984504, ...
# 2811  [0.0, 2.166761388355011, 9.47958937649956, 8.7...

# %%
redundancy_score, result_local_optima, neighbourhoods = redundancy(bus_result,df_work,similarity_threshold=0.10,result_order_qdc=(0,2,1))
